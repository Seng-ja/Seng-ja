# %% [markdown]
# <a href="https://colab.research.google.com/github/Seng-ja/Seng-ja/blob/main/Model_Evaluation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.linear_model import LinearRegression
# if cann't install sklearn just just install from notebook  (!pip install sklearn)

# %%
myfolder = "drive/My Drive/Learn_Notebooks/DATA/"
import pandas as pd
df =pd.read_csv(myfolder + "regression-one.csv")
df.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
df.rename(columns ={'Life expectancy':'life expect'},inplace = True)
df.head()
# Out:
#        Country  Year      Status  life expect  Adult Mortality  infant deaths  \
# 0  Afghanistan  2015  Developing         65.0            263.0             62
# 1  Afghanistan  2014  Developing         59.9            271.0             64
# 2  Afghanistan  2013  Developing         59.9            268.0             66
# 3  Afghanistan  2012  Developing         59.5            272.0             69
# 4  Afghanistan  2011  Developing         59.2            275.0             71
#
#    Alcohol  percentage expenditure  Hepatitis B  Measles  ...  Polio  \
# 0     0.01               71.279624         65.0     1154  ...    6.0
# 1     0.01               73.523582         62.0      492  ...   58.0
# 2     0.01               73.219243         64.0      430  ...   62.0
# 3     0.01               78.184215         67.0     2787  ...   67.0
# 4     0.01                7.097109         68.0     3013  ...   68.0
#
#    Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
df.dropna()
# Out:
#           Country  Year      Status  life expect  Adult Mortality  \
# 0     Afghanistan  2015  Developing         65.0            263.0
# 1     Afghanistan  2014  Developing         59.9            271.0
# 2     Afghanistan  2013  Developing         59.9            268.0
# 3     Afghanistan  2012  Developing         59.5            272.0
# 4     Afghanistan  2011  Developing         59.2            275.0
# ...           ...   ...         ...          ...              ...
# 2933     Zimbabwe  2004  Developing         44.3            723.0
# 2934     Zimbabwe  2003  Developing         44.5            715.0
# 2935     Zimbabwe  2002  Developing         44.8             73.0
# 2936     Zimbabwe  2001  Developing         45.3            686.0
# 2937     Zimbabwe  2000  Developing         46.0            665.0
#
#       infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  \
# 0                62     0.01               71.279624         65.0     1154
# ...

# %%
df.shape
# Out:
# (2938, 22)

# %%
df.isnull().any()
# Out:
# Country                            False
# Year                               False
# Status                             False
# life expect                         True
# Adult Mortality                     True
# infant deaths                      False
# Alcohol                             True
# percentage expenditure             False
# Hepatitis B                         True
# Measles                            False
# BMI                                 True
# under-five deaths                  False
# Polio                               True
# Total expenditure                   True
# Diphtheria                          True
# HIV/AIDS                           False
# GDP                                 True
# Population                          True
# thinness 1-19 years                 True
# thinness 5-9 years                  True
# Income composition of resources     True
# Schooling                           True
# dtype: bool

# %%
df[df.isnull().any(axis =1)]
# Out:
#        Country  Year      Status  life expect  Adult Mortality  infant deaths  \
# 32     Algeria  2015  Developing         75.6             19.0             21
# 44     Algeria  2003  Developing         71.7            146.0             20
# 45     Algeria  2002  Developing         71.6            145.0             20
# 46     Algeria  2001  Developing         71.4            145.0             20
# 47     Algeria  2000  Developing         71.3            145.0             21
# ...        ...   ...         ...          ...              ...            ...
# 2918    Zambia  2003  Developing         46.4             64.0             39
# 2919    Zambia  2002  Developing         45.5             69.0             41
# 2920    Zambia  2001  Developing         44.6            611.0             43
# 2921    Zambia  2000  Developing         43.8            614.0             44
# 2922  Zimbabwe  2015  Developing         67.0            336.0             22
#
# ...

# %%
df = df.dropna()

# %%
df.shape
# Out:
# (1649, 22)

# %%
df =df[df.isnull().any(axis =1)]
df
# Out:
# Empty DataFrame
# Columns: [Country, Year, Status, life expect, Adult Mortality, infant deaths, Alcohol, percentage expenditure, Hepatitis B, Measles, BMI, under-five deaths, Polio, Total expenditure, Diphtheria, HIV/AIDS, GDP, Population, thinness 1-19 years, thinness 5-9 years, Income composition of resources, Schooling]
# Index: []
#
# [0 rows x 22 columns]

# %%
df.shape
# Out:
# (0, 22)

# %%
myfolder = "drive/My Drive/Learn_Notebooks/DATA/"
import pandas as pd
df1 =pd.read_csv(myfolder + "regression-one.csv")
df1.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult Mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
df1 = df.dropna()

# %%
df1.shape
# Out:
# (0, 22)

# %%
slr = LinearRegression()

# %%
df1['Schooling'].value_counts()
# Out:
# Series([], Name: Schooling, dtype: int64)

# %%
df1.rename(columns ={'Life expectancy':'life expect'},inplace = True)
df1.head()
# Out:
# Empty DataFrame
# Columns: [Country, Year, Status, life expect, Adult Mortality, infant deaths, Alcohol, percentage expenditure, Hepatitis B, Measles, BMI, under-five deaths, Polio, Total expenditure, Diphtheria, HIV/AIDS, GDP, Population, thinness 1-19 years, thinness 5-9 years, Income composition of resources, Schooling]
# Index: []
#
# [0 rows x 22 columns]

# %%
X =df1 ['Schooling']
y =df1 ['life expect']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, test_size = 0.3, random_state = 100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-45-8a667f9e6ffd> in <module>
#       1 from sklearn.model_selection import train_test_split
# ----> 2 X_train, X_test, y_train, y_test = train_test_split(X, y, train_size = 0.7, test_size = 0.3, random_state = 100)
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2419     n_samples = _num_samples(arrays[0])
#    2420     n_train, n_test = _validate_shuffle_split(
# -> 2421         n_samples, test_size, train_size, default_test_size=0.25
#    2422     )
#    2423
#
# /usr/local/lib/python3.7/dist-packages/sklearn/model_selection/_split.py in _validate_shuffle_split(n_samples, test_size, train_size, default_test_size)
#    2099             "With n_samples={}, test_size={} and train_size={}, the "
# ...

# %%
# Adding additional column to the train and test data
X_train_lm = np.asarray(X_train).reshape(-1,1)
X_test_lm = np.asarray(X_test).reshape(-1,1)

# %%
X_train_lm.shape

# %%
X_test_lm.shape

# %%
y_train.shape

# %%
slr = LinearRegression().fit(X_train_lm, y_train)

# %%
slryhat = slr.predict(X_train_lm) 
#slryhat1 = slr.predict(X_test_lm)

# %%
print(slryhat[0:4])

# %%
print(slryhat1[0:4])

# %%
from sklearn.metrics import mean_squared_error
slr_MSE = mean_squared_error(df['life expect'],slryhat)
print('MSR for simple linear Regression:',slr_MSE)

# %%
MLRX =df[['GDP','Alcohol','BMI','Schooling']]
mlr= LinearRegression()
mlr.fit(MLRX, y)

# %%
mlryhat = mlr.predict(MLRX)
print(mlryhat[0:4])

# %%
mlr_mse =mean_squared_error(df['life expect'],mlryhat)
print('MSE for Multiple Linear Regression: ',mlr_mse)

# %%
mlr_r2 = mlr.score(MLRX, y)
print('R2 for Multiple Linear Regression:',mlr_r2)

# %%
prX = df['Schooling']
f= np.polyfit(prX, y,3)
pr = np.poly1d(f)

# %%
pryhat = pr(prX)
print(pryhat)

# %%
pr_mse = mean_squared_error(df['life expect'],pryhat)
print('MSE for Polynomial Regression: ',pr_mse)

# %%
from sklearn.metrics import r2_score
pr_r2 = r2_score (df['life expect'],pryhat)
print('R2 for Polynomial Regression: ', pr_r2)

# %%
print('Multiple Linear Regression')
print('MSE for Multiple Linear Regression: ',mlr_mse)
print('R2 for Multiple Linear Regression: ', mlr_r2)

# %%
print('Polynomial  Regression')
print('MSE for Polynomial Regression: ',pr_mse)
print('R2 for Polynomial Regression: ', pr_r2)
